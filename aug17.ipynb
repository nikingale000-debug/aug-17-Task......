# %%
file = "myfile.pdf"
count = file.index(".")
name = file[0:count]

print(file.upper())
print(file.lower())
print(file.title())
print(file.capitalize())
print(file.strip())
print(file.replace("pdf", "docx"))
print(file.split())
print(file.startswith("my"))
print(file.endswith("pdf"))

extension = file[count+1:]
print(extension.isalnum())
print(extension.isalpha())
print(extension.isdigit())
print(extension.islower())
print(extension.isupper())
print(file.replace("myfile", "newfile"))
# Out:
# MYFILE.PDF
# myfile.pdf
# Myfile.Pdf
# Myfile.pdf
# myfile.pdf
# myfile.docx
# ['myfile.pdf']
# True
# True
# True
# True
# False
# True
# False
# newfile.pdf
